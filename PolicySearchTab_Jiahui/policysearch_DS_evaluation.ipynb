# %%
from policy_search_ds import *
# Out:
# Using TensorFlow backend.
# 3.6.12 |Anaconda, Inc.| (default, Sep  9 2020, 00:29:25) [MSC v.1916 64 bit (AMD64)]

# %%
# The basics
# %matplotlib inline
import pickle 

import matplotlib.pyplot as plt
import time
import itertools
import matplotlib
import pickle
import pandas as pd

import numpy as np
import sys
import os
import collections
from collections import namedtuple

file = open("./data/data_train/train2",'rb')
train = pickle.load(file)
file.close()
    
plt.title('episode_reward for id=2')
plt.plot(train.episode_rewards)

# %%
    file = open("./data/data_test/test_S0_N02", 'rb')
    test = pickle.load(file)
    file.close()
    

plt.plot(test.episode_rewards)

# %%
    file = open("./data/data_test/test_S0_N12", 'rb')
    test = pickle.load(file)
    file.close()
    

plt.plot(test.episode_rewards)

# %%
    file = open("./data/data_test/test_S1_N02",'rb')
    test = pickle.load(file)
    file.close()
    

plt.plot(test.episode_rewards)

# %%
    file = open("./data/data_test/test_S0_N02", 'rb')
    test = pickle.load(file)
    file.close()
    

plt.plot(test.episode_rewards)
