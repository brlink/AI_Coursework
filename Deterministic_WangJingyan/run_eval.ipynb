# %%
import sys
sys.path.append("..")

import numpy as np
import matplotlib.pyplot as plt

from QlernNN_WangJingyan.q_learning_nn import *
from QlernNN_WangJingyan.evaluation import*

# %% [markdown]
# ## evaluating using rewards as metrics

# %%
for s_n in range(4):

    #set stochastic and noisy from binary(00) to binary(11)
    stochastic =(s_n//2)%2
    noisy = s_n%2 

    plt.figure()
    plt.title("rewards per episode when stochastic={} and noise={}".format(stochastic, noisy))
    plt.xlabel("episodes")
    plt.ylabel("rewards")
    for i in range(10):
        stats = load_variable("./data/stats_training/stats_train0{}_{}{}.dat".format(i, stochastic, noisy))
        plot_rewards(stats, i)
    plt.legend()
    plt.savefig("./figures/figure{}.pdf".format(s_n))
